# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score

# %%
df = pd.read_csv('marks.csv')
print("Data loaded successfully. Here are the first 5 rows:")
print(df.head())
# Out:
# Data loaded successfully. Here are the first 5 rows:
#    hours  marks
# 0    1.0     12
# 1    1.5     13
# 2    2.0     14
# 3    2.5     20
# 4    3.0     23

# %%
# prepare the data
x = df.iloc[:, :-1].values
y = df.iloc[:, 1].values
#split into training and test sets(80/20 split)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print("Data split into training and testing sets.")
# Out:
# Data split into training and testing sets.

# %%
regressor = LinearRegression()
regressor.fit(x_train, y_train)

print("Training complete.")
# Out:
# Training complete.

# %%
#predict the scores
y_pred = regressor.predict(x_test)
#calculate evaluation metrics
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error: {mae:.2f}")
print(f"R-squared scores: {r2:.2f}")
# Out:
# Mean Absolute Error: 7.19
# R-squared scores: 0.70

# %%
#plotting the regression line
line = regressor.coef_* x + regressor.intercept_

plt.figure(figsize=(10,6))
plt.scatter(x, y, color = 'royalblue', edgecolor='black',s=100, label='Data points')
plt.plot(x, line, color='crimson', linewidth=2, label='Regression Line')
plt.title('Hours vs Scores', fontsize=16)
plt.xlabel('Hours Studied', fontsize=14)
plt.ylabel('Scores Obtained', fontsize=14)
plt.legend()
plt.show()

# %%
hours = float(input("enter hours: "))
prediction = regressor.predict([[hours]])
print(f"predicted score for {hours} hours of study is {prediction[0]:.2f}")
# Out:
# predicted score for 5.0 hours of study is 39.59
